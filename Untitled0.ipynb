# %% [markdown]
# <a href="https://colab.research.google.com/github/aldogg10/Mineria_de_Datos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ###Introduccion

# %% [markdown]
# ####Conceptos

# %% [markdown]
# Mineria de datos: Es un proceso en el cual se analizan grandes volumenes de datos para descubrir patrones, tendencias

# %% [markdown]
# #####Ciencia de datos
